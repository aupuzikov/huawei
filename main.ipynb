# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Бинарный-классификатор-голосов" data-toc-modified-id="Бинарный-классификатор-голосов-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Бинарный классификатор голосов</a></span><ul class="toc-item"><li><span><a href="#всякие-установки" data-toc-modified-id="всякие-установки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>всякие установки</a></span></li><li><span><a href="#всякие-импорты" data-toc-modified-id="всякие-импорты-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>всякие импорты</a></span></li><li><span><a href="#загрузка-датасета" data-toc-modified-id="загрузка-датасета-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>загрузка датасета</a></span></li><li><span><a href="#нейроночки" data-toc-modified-id="нейроночки-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>нейроночки</a></span><ul class="toc-item"><li><span><a href="#обычная-модель" data-toc-modified-id="обычная-модель-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>обычная модель</a></span><ul class="toc-item"><li><span><a href="#датасет" data-toc-modified-id="датасет-1.4.1.1"><span class="toc-item-num">1.4.1.1&nbsp;&nbsp;</span>датасет</a></span></li><li><span><a href="#цикл-тренировки" data-toc-modified-id="цикл-тренировки-1.4.1.2"><span class="toc-item-num">1.4.1.2&nbsp;&nbsp;</span>цикл тренировки</a></span></li><li><span><a href="#проверка-на-тесте" data-toc-modified-id="проверка-на-тесте-1.4.1.3"><span class="toc-item-num">1.4.1.3&nbsp;&nbsp;</span>проверка на тесте</a></span></li><li><span><a href="#резы-на-тесте" data-toc-modified-id="резы-на-тесте-1.4.1.4"><span class="toc-item-num">1.4.1.4&nbsp;&nbsp;</span>резы на тесте</a></span></li></ul></li><li><span><a href="#модель-с-пересекающимися-окнами-для-FFT-(а-ля-STFT)" data-toc-modified-id="модель-с-пересекающимися-окнами-для-FFT-(а-ля-STFT)-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>модель с пересекающимися окнами для FFT (а ля STFT)</a></span><ul class="toc-item"><li><span><a href="#датасет" data-toc-modified-id="датасет-1.4.2.1"><span class="toc-item-num">1.4.2.1&nbsp;&nbsp;</span>датасет</a></span></li><li><span><a href="#цикл" data-toc-modified-id="цикл-1.4.2.2"><span class="toc-item-num">1.4.2.2&nbsp;&nbsp;</span>цикл</a></span></li><li><span><a href="#резы-на-тесте" data-toc-modified-id="резы-на-тесте-1.4.2.3"><span class="toc-item-num">1.4.2.3&nbsp;&nbsp;</span>резы на тесте</a></span></li></ul></li><li><span><a href="#модель-с-окном-ханна-для-STFT" data-toc-modified-id="модель-с-окном-ханна-для-STFT-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>модель с окном ханна для STFT</a></span><ul class="toc-item"><li><span><a href="#датасет" data-toc-modified-id="датасет-1.4.3.1"><span class="toc-item-num">1.4.3.1&nbsp;&nbsp;</span>датасет</a></span></li><li><span><a href="#цикл" data-toc-modified-id="цикл-1.4.3.2"><span class="toc-item-num">1.4.3.2&nbsp;&nbsp;</span>цикл</a></span></li><li><span><a href="#резы-на-тесте" data-toc-modified-id="резы-на-тесте-1.4.3.3"><span class="toc-item-num">1.4.3.3&nbsp;&nbsp;</span>резы на тесте</a></span></li></ul></li><li><span><a href="#модель-с-переводом-в-амплитуды-логарифмическую-шкалу" data-toc-modified-id="модель-с-переводом-в-амплитуды-логарифмическую-шкалу-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>модель с переводом в амплитуды логарифмическую шкалу</a></span><ul class="toc-item"><li><span><a href="#датасет" data-toc-modified-id="датасет-1.4.4.1"><span class="toc-item-num">1.4.4.1&nbsp;&nbsp;</span>датасет</a></span></li><li><span><a href="#цикл" data-toc-modified-id="цикл-1.4.4.2"><span class="toc-item-num">1.4.4.2&nbsp;&nbsp;</span>цикл</a></span></li><li><span><a href="#резы-на-тесте" data-toc-modified-id="резы-на-тесте-1.4.4.3"><span class="toc-item-num">1.4.4.3&nbsp;&nbsp;</span>резы на тесте</a></span></li></ul></li><li><span><a href="#используем-MELSPEC" data-toc-modified-id="используем-MELSPEC-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>используем MELSPEC</a></span><ul class="toc-item"><li><span><a href="#датасет" data-toc-modified-id="датасет-1.4.5.1"><span class="toc-item-num">1.4.5.1&nbsp;&nbsp;</span>датасет</a></span></li><li><span><a href="#цикл" data-toc-modified-id="цикл-1.4.5.2"><span class="toc-item-num">1.4.5.2&nbsp;&nbsp;</span>цикл</a></span></li><li><span><a href="#резы-на-тесте" data-toc-modified-id="резы-на-тесте-1.4.5.3"><span class="toc-item-num">1.4.5.3&nbsp;&nbsp;</span>резы на тесте</a></span></li></ul></li></ul></li><li><span><a href="#тензорборда-и-заключение" data-toc-modified-id="тензорборда-и-заключение-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>тензорборда и заключение</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Бинарный классификатор голосов
#
#
# Задача:  Классификатор мужских и женских голосов на базе LibriTTS
#
# На что мы обращаем внимание при оценке результата:
#
# 1 Код
#
#     структурированный хорошо комментированный и понятный (отделены: предобработка, train/test),
#     есть краткое readme: как запустить и какие дополнительные данные использовали
#
# 2 Описание результатов:
#
#     Анализ данных
#     Выбор метода (Как выбирали?),
#     Описание экспериментов
#     Анализ результатов и аргументированные предложения по дальнейшему улучшению
#
#
# Важно:  мы оцениваем ваше знания и навыки  в ЦОС, ML/DL, программировании и культуре проведения экспериментов. Мы НЕ рекомендуем фокусироваться на больших датасетах и использовании многих GPU. Важнее не показать state-of-the-art результат в плане точности/качества решения, а продемонстрировать решение на разумном датасете и продемонстрировать адекватное решение (при условии заданного датасета и вычислительных мощностей), раскрывающее навыки в постановке задачи обучения, постановке эксперимента и анализе его результатов.

# %% [markdown]
# ## всякие установки

# %%
# !pip3 install PySoundFile
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# !pip3 install librosa
# !pip3 install torchmetrics
# !pip3 install json
# !pip3 install pytorch_lightning
# !pip3 install ipywebrtc
# Out:
# Requirement already satisfied: PySoundFile in d:\users\eskander\venv\ml-postflop\lib\site-packages (0.9.0.post1)
# Requirement already satisfied: cffi>=0.6 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from PySoundFile) (1.15.0)
# Requirement already satisfied: pycparser in d:\users\eskander\venv\ml-postflop\lib\site-packages (from cffi>=0.6->PySoundFile) (2.21)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Requirement already satisfied: torch in d:\users\eskander\venv\ml-postflop\lib\site-packages (1.10.0+cu113)
# Requirement already satisfied: torchvision in d:\users\eskander\venv\ml-postflop\lib\site-packages (0.11.0+cu113)
# Requirement already satisfied: torchaudio in d:\users\eskander\venv\ml-postflop\lib\site-packages (0.10.0+cu113)
# Requirement already satisfied: typing-extensions in d:\users\eskander\venv\ml-postflop\lib\site-packages (from torch) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from torchvision) (8.4.0)
# Requirement already satisfied: numpy in d:\users\eskander\venv\ml-postflop\lib\site-packages (from torchvision) (1.21.4)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: librosa in d:\users\eskander\venv\ml-postflop\lib\site-packages (0.9.2)
# Requirement already satisfied: numpy>=1.17.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from librosa) (1.21.4)
# Requirement already satisfied: numba>=0.45.1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from librosa) (0.55.1)
# Requirement already satisfied: scipy>=1.2.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from librosa) (1.7.2)
# Requirement already satisfied: soundfile>=0.10.2 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: joblib>=0.14 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from librosa) (1.0.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from librosa) (1.0.1)
# Requirement already satisfied: pooch>=1.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from librosa) (21.2)
# Requirement already satisfied: audioread>=2.1.9 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: resampy>=0.2.2 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from librosa) (0.4.0)
# Requirement already satisfied: decorator>=4.0.10 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from librosa) (5.1.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from numba>=0.45.1->librosa) (0.38.0)
# Requirement already satisfied: setuptools in d:\users\eskander\venv\ml-postflop\lib\site-packages (from numba>=0.45.1->librosa) (59.5.0)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: appdirs>=1.3.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pooch>=1.0->librosa) (2.26.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from scikit-learn>=0.19.1->librosa) (3.0.0)
# Requirement already satisfied: cffi>=1.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in d:\users\eskander\venv\ml-postflop\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.7)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: torchmetrics in d:\users\eskander\venv\ml-postflop\lib\site-packages (0.6.0)
# Requirement already satisfied: torch>=1.3.1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from torchmetrics) (1.10.0+cu113)
# Requirement already satisfied: numpy>=1.17.2 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from torchmetrics) (1.21.4)
# Requirement already satisfied: packaging in d:\users\eskander\venv\ml-postflop\lib\site-packages (from torchmetrics) (21.2)
# Requirement already satisfied: typing-extensions in d:\users\eskander\venv\ml-postflop\lib\site-packages (from torch>=1.3.1->torchmetrics) (3.10.0.2)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from packaging->torchmetrics) (2.4.7)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
# Requirement already satisfied: pytorch_lightning in d:\users\eskander\venv\ml-postflop\lib\site-packages (1.5.10)
# Requirement already satisfied: numpy>=1.17.2 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pytorch_lightning) (1.21.4)
# Requirement already satisfied: PyYAML>=5.1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pytorch_lightning) (5.4.1)
# Requirement already satisfied: setuptools==59.5.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pytorch_lightning) (59.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pytorch_lightning) (4.62.3)
# Requirement already satisfied: future>=0.17.1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pytorch_lightning) (0.18.2)
# Requirement already satisfied: torchmetrics>=0.4.1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pytorch_lightning) (0.6.0)
# Requirement already satisfied: pyDeprecate==0.3.1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pytorch_lightning) (0.3.1)
# Requirement already satisfied: torch>=1.7.* in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pytorch_lightning) (1.10.0+cu113)
# Requirement already satisfied: packaging>=17.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pytorch_lightning) (21.2)
# Requirement already satisfied: tensorboard>=2.2.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pytorch_lightning) (2.9.1)
# Requirement already satisfied: typing-extensions in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pytorch_lightning) (3.10.0.2)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pytorch_lightning) (2021.11.0)
# Requirement already satisfied: aiohttp in d:\users\eskander\venv\ml-postflop\lib\site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.8.1)
# Requirement already satisfied: requests in d:\users\eskander\venv\ml-postflop\lib\site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.26.0)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from packaging>=17.0->pytorch_lightning) (2.4.7)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: grpcio>=1.24.3 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.41.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.3.5)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from tensorboard>=2.2.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: absl-py>=0.4 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.0.0)
# Requirement already satisfied: wheel>=0.26 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.37.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.19.1)
# Requirement already satisfied: colorama in d:\users\eskander\venv\ml-postflop\lib\site-packages (from tqdm>=4.41.0->pytorch_lightning) (0.4.4)
# Requirement already satisfied: six in d:\users\eskander\venv\ml-postflop\lib\site-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch_lightning) (1.16.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: importlib-metadata>='4.4' in d:\users\eskander\venv\ml-postflop\lib\site-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning) (4.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2021.10.8)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (4.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (5.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.7.2)
# Requirement already satisfied: asynctest==0.13.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (21.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from importlib-metadata>='4.4'->markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\users\eskander\venv\ml-postflop\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (3.1.1)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ipywebrtc in d:\users\eskander\venv\ml-postflop\lib\site-packages (0.6.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## всякие импорты

# %%
import pandas as pd
import pickle
import numpy as np
import os
import librosa
import torchmetrics
import time
from tqdm.notebook import tqdm
import librosa.display as ld

# %%
import torch
import torchaudio
import torchaudio.datasets.libritts as libritts
import pytorch_lightning
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
from torch.utils.data import DataLoader, IterableDataset, Dataset
torch.__version__, torchaudio.__version__, pytorch_lightning.__version__
# Out:
# ('1.10.0+cu113', '0.10.0+cu113', '1.5.10')

# %% [markdown]
# ## загрузка датасета

# %%
l_tts_train = libritts.LIBRITTS(root='.',download=True)
l_tts_train

# %%
l_tts_test = libritts.LIBRITTS(root='.',url='test-clean',download=True)
l_tts_test

# %%
work_dir='.'
data_path = 'Y:/Documents/projects/libri_tts/freq_imgs'
data_train = os.path.join(data_path , 'train')
data_test = os.path.join(data_path ,'test')
os.makedirs(data_train, exist_ok=True)
os.makedirs(data_test, exist_ok=True)
data_train
# Out:
# 'Y:/Documents/projects/libri_tts/freq_imgs\\train'

# %%
def load_speakers():
    id_to_sex = dict()
    import os
    with open(r'LibriTTS/SPEAKERS.txt', mode='r') as f:
        lines = f.readlines()
    for line in lines[12:]:
        tokens = line.split('|')
        id_to_sex[int(tokens[0])] = 0 if tokens[1].strip() == 'M' else 1
    return id_to_sex


id_2_sex_map = load_speakers()

# %%
len(l_tts_train), len(l_tts_test)
# Out:
# (33236, 4837)

# %%
first_example = l_tts_train[0]
first_example
# Out:
# (tensor([[-0.0377, -0.0374, -0.0386,  ..., -0.0211, -0.0216, -0.0210]]),
#  24000,
#  'The Law.',
#  'The Law.',
#  1034,
#  121119,
#  '1034_121119_000001_000001')

# %%
import IPython.display as ipd
ipd.Audio(first_example[0].numpy(), rate=first_example[1])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def to_freq_imgs(libri_dataset, path: str):
    os.makedirs(path, exist_ok=True)
    for k in tqdm(range(len(libri_dataset))):
        sound = libri_dataset[k]
        spectr = make_spectr(sound[0],
                             sound[1],
                             top_n_freq=TOP_N_FREQ,
                             windows_count=WINDOWS_COUNT)
        img = np.abs(spectr.transpose())
        sex = id_2_sex_map[sound[4]]
        file_name = f"{path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{k}_{sex}.npy"
        if not os.path.exists(file_name):
            with open(file_name, "wb") as f:
                np.save(f, img)

# %%
first_example[0].shape
# Out:
# torch.Size([1, 16320])

# %%
# посмотрим на результаты ФФТ
rfft_first_example = np.fft.rfft(first_example[0].numpy())
ld.specshow(np.abs(rfft_first_example),)
rfft_first_example
# Out:
# array([[-1.57334076e+02+0.j        , -2.90118119e-01+2.51943349j,
#          4.29763696e+00-1.17624757j, ..., -2.61175426e-02-0.0040488j ,
#         -6.37991131e-03-0.01121272j, -4.80041504e-02+0.j        ]])

# %%
# делаем спектр из семпла с окнами в кол-ве windows_count без перекрытия
# и с определённым максимальным кол-вом бинов частот top_n_freq
def make_spectr(numpy_signal: np.array,
                signal_rate: int,
                windows_count=1000,
                top_n_freq=4000) -> np.array:
    spectr = np.zeros((windows_count, top_n_freq, 1), dtype=np.cdouble)
    windows_size = int(len(numpy_signal[0]) / windows_count)
    windows = np.zeros((windows_count, 1, len(numpy_signal[0])))
    # print(windows_size)
    for i in range(windows_count):
        # window = np.zeros((1, len(numpy_signal[0])))
        windows[i, 0, i * windows_size:(i + 1) *
                windows_size] = numpy_signal[0, i * windows_size:(i + 1) *
                                             windows_size]
        # windows[i] = window
        # print(window.shape)
    rfft_signals = np.fft.rfft(windows, axis=2)
    # print(rfft_signal.shape, rfft_signal)
    spectr = rfft_signals[:, :, :top_n_freq]
    return spectr.transpose(0, 2, 1)

# %%
# делаем спектр из семпла с окнами в кол-ве windows_count без перекрытия
# и с определённым максимальным кол-вом бинов частот top_n_freq
def make_spectr_v2(numpy_signal: np.array,
                signal_rate: int,
                windows_count=1000,
                window_type='boxcar',
                top_n_freq=4000) -> np.array:
    n_samples = len(numpy_signal[0]) 
    return librosa.stft(numpy_signal[0],
                                      hop_length=int(n_samples/windows_count) ,
                                      window=window_type,
                                      n_fft=n_samples,
                                      win_length=int(n_samples/windows_count) )[:top_n_freq,:windows_count]

# %%
# %%time
spectr = make_spectr(l_tts_train[1][0].numpy(),
                     l_tts_train[1][1],
                     windows_count=300,
                     top_n_freq=20000)
ld.specshow(np.abs(spectr.reshape(spectr.shape[:2])).transpose(),
            y_axis='fft',
            x_axis='frames',
            sr=l_tts_train[1][1])
spectr.shape
# Out:
# Wall time: 19.7 s
# (300, 181321, 1)

# %%
# %%time
spectrv2 = make_spectr_v2(l_tts_train[1][0].numpy(),
                        l_tts_train[1][1],
                        windows_count=300,
                        top_n_freq=20000)
ld.specshow(
    np.abs(spectrv2),
    y_axis='fft',
    x_axis='frames',
    sr=l_tts_train[1][1])
# Out:
# Wall time: 23.5 s

# %%
# %%time
spectr = make_spectr_v2(l_tts_train[1][0].numpy(),
                        l_tts_train[1][1],
                        windows_count=300,
                        window_type='hann',
                        top_n_freq=20000)
ld.specshow(np.abs(spectr),
            y_axis='fft',
            hop_length=int(len(l_tts_train[1][0][0]) / 300),
            x_axis='frames',
            sr=l_tts_train[1][1])
spectr.shape
# Out:
# Wall time: 24.7 s
# (20000, 300)

# %% [markdown]
# кажется стоило бы использовать **librosa.stft** но как мы видим на удивления в лоб получается быстрее, возможно из-за отсуствие оконной функции а ля Hahn или ещё чего-нибудь в топорном варианте.

# %%
WINDOWS_COUNT = 300 # количество окон, на которые разбивается семлп
TOP_N_FREQ = 1000 # только первые 1000 бинов частот из fft преобразования
TRAIN_SET_SIZE = 15000 # возьмём только половину датасета
VALID_SET_SIZE = 2000

# %%
y = np.array([id_2_sex_map[s[4]] for s in tqdm(l_tts_train)])
y
# Out:
#   0%|          | 0/33236 [00:00<?, ?it/s]
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# поскольку классы сбалансированы не будем мучаться с весами семплов или ещё какими-нибудь приседаниями
(y == 1).sum(), len(y)
# Out:
# (17629, 33236)

# %%
idxs = np.arange(TRAIN_SET_SIZE + VALID_SET_SIZE)
np.random.seed(42)
np.random.shuffle(idxs)

valid_idxs = idxs[:VALID_SET_SIZE]
train_idxs = idxs[VALID_SET_SIZE:VALID_SET_SIZE + TRAIN_SET_SIZE]
test_idxs = np.arange(len(l_tts_test))
len(train_idxs), len(valid_idxs), len(test_idxs)
# Out:
# (15000, 2000, 4837)

# %% [markdown]
# ## нейроночки

# %% [markdown]
# ### обычная модель

# %%
EPOCHS = 50
BATCH_SIZE = 256

# %%
def make_model():
    model = torch.nn.Sequential(
        torch.nn.Conv2d(1, 15, kernel_size=(3,3), stride=2, padding_mode='zeros'),
        torch.nn.MaxPool2d(kernel_size=(3,3), stride=2),
        torch.nn.LeakyReLU(),
        torch.nn.Conv2d(15, 45, kernel_size=(5,5), stride=2, padding_mode='zeros'),
        torch.nn.MaxPool2d(kernel_size=(5,5), stride=2),
        torch.nn.LeakyReLU(),
        torch.nn.Conv2d(45, 65, kernel_size=(5,5), stride=2, padding_mode='zeros'),
        torch.nn.MaxPool2d(kernel_size=(5,5), stride=2),
        torch.nn.LeakyReLU(),
        torch.nn.Flatten(),
        torch.nn.Linear(780, 1),
        torch.nn.Sigmoid()
    )
    return model.cuda()

# %%
class Model(pytorch_lightning.LightningModule):
    def __init__(self, model=make_model()):
        super().__init__()
        self.model = model
        self.loss = torch.nn.BCELoss()
        self.train_acc = torchmetrics.Accuracy()
        self.valid_acc = torchmetrics.Accuracy()

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        y_h = self.model(x)
        l = self.loss(y_h, y[:, None])
        self.train_acc(y_h, y[:, None].int())
        self.log('train_acc',
                 self.train_acc,
                 prog_bar=True,
                 on_step=True,
                 on_epoch=False)
        return l

    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_h = self.model(x)
        l = self.loss(y_h, y[:, None])
        self.valid_acc(y_h, y[:, None].int())
        self.log('valid_acc',
                 self.valid_acc,
                 prog_bar=True,
                 on_step=True,
                 on_epoch=True)
        self.log('valid_loss', l.item(), on_step=True, on_epoch=True)
        return l

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.model.parameters(),
                                     lr=1e-3,
                                     betas=(0.9, 0.999),
                                     eps=1e-5)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                    step_size=15,
                                                    gamma=0.1)
        return [optimizer], [{"scheduler": scheduler, "interval": "epoch"}]

# %% [markdown]
# #### датасет

# %%
class LibriDataset(Dataset):
    def __init__(self, libri_dataset, idxs: list, path: str):
        self.libri_dataset = libri_dataset
        self.idxs = idxs
        self.path = path

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, index):
        random_index = self.idxs[index]
        if not (os.path.exists(
                f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_0.npy"
        ) or os.path.exists(
                f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_1.npy"
        )):
            sound = self.libri_dataset[random_index]
            spectr = make_spectr(sound[0],
                                 sound[1],
                                 top_n_freq=TOP_N_FREQ,
                                 windows_count=WINDOWS_COUNT)
            img = np.abs(spectr.transpose())
            sex = id_2_sex_map[sound[4]]
            file_name = f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_{sex}.npy"
            with open(file_name, "wb") as f:
                np.save(f, img)
        else:
            file_name = f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_0.npy"
            if os.path.exists(file_name):
                with open(file_name, "rb") as f:
                    img = np.load(f, allow_pickle=True)
                    sex = 0
            else:
                file_name = f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_1.npy"
                if os.path.exists(file_name):
                    with open(file_name, "rb") as f:
                        img = np.load(f, allow_pickle=True)
                        sex = 1

        return torch.tensor(img).float().cuda(), torch.tensor(
            sex).float().cuda()


train_dataloader = DataLoader(LibriDataset(l_tts_train, train_idxs,
                                            data_train),
                              batch_size=BATCH_SIZE,
                              num_workers=0,
                              shuffle=True)
valid_dataloader = DataLoader(LibriDataset(l_tts_train, valid_idxs,
                                            data_train),
                              num_workers=0,
                              batch_size=BATCH_SIZE)

# %% [markdown]
# #### цикл тренировки

# %%
early_stop_callback = EarlyStopping(monitor='valid_loss',
                                    min_delta=0.001,
                                    patience=30,
                                    verbose=True,
                                    mode='min')
val_loss_checkpoint = ModelCheckpoint(monitor='valid_loss',
                                      dirpath=work_dir +
                                      './models/',
                                      filename='{epoch:02d}-{valid_loss:.4f}',
                                      save_top_k=1,
                                      verbose=True,
                                      mode='min')

# %%
model = Model()
trainer = Trainer(max_epochs=EPOCHS, gpus=1 , callbacks=[early_stop_callback, val_loss_checkpoint],)# resume_from_checkpoint=work_dir+'./pytorch_models/*' )
trainer.fit(model=model, train_dataloader=train_dataloader, val_dataloaders=valid_dataloader)
f"best checkpoint path {val_loss_checkpoint.best_model_path}"
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | model     | Sequential | 371 K
# 1 | loss      | BCELoss    | 0
# 2 | train_acc | Accuracy   | 0
# 3 | valid_acc | Accuracy   | 0
# -----------------------------------------
# 371 K     Trainable params
# 0         Non-trainable params
# 371 K     Total params
# 1.487     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# 'best checkpoint path '

# %% [markdown]
# #### проверка на тесте

# %%
# model.load_from_checkpoint(val_loss_checkpoint.best_model_path)
model = Model()
model.load_state_dict(torch.load('.\\models\\epoch=07-valid_loss=0.4844.ckpt')['state_dict'])
model = model.cuda()

# %%
test_idxs = np.arange(VALID_SET_SIZE + TRAIN_SET_SIZE, VALID_SET_SIZE + TRAIN_SET_SIZE + 3000)

test_dataloader = DataLoader(LibriDataset(l_tts_train, test_idxs,
                                            data_train),
                              num_workers=0,
                              batch_size=BATCH_SIZE)

# %%
with torch.no_grad():
    y_tests = []
    y_test_preds = []
    for x_test, y_test in tqdm(LibriDataset(l_tts_train, test_idxs,
                                                data_train)):
        y_tests.append(y_test.item())
        y_test_preds.append(model.forward(x_test.unsqueeze(0).cuda()).item())
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]

# %% [markdown]
# #### резы на тесте

# %%
# средняя точность на тесте
((np.array(y_test_preds) > 0.5).astype(int) == np.array(y_tests)).mean()
# Out:
# 0.7266666666666667

# %% [markdown]
# не бог весть что, но всё же. Есть идея резать на окна не дуболомно, а с перекрытием. Этим и займёмся.

# %% [markdown]
# ### модель с пересекающимися окнами для FFT (а ля STFT)

# %%
def make_overlapped_spectr(numpy_signal: np.array,
                           signal_rate: int,
                           windows_count=1000,
                           overlapping_area=0.5,
                           top_n_freq=4000) -> np.array:
    spectr = np.zeros((windows_count, top_n_freq, 1), dtype=np.cdouble)
    windows_size = int(len(numpy_signal[0]) / windows_count)
    windows = np.zeros((windows_count, 1, len(numpy_signal[0])))
    
    for i in range(windows_count):
        
        left_border = i * windows_size
        right_border = (i + 1) * windows_size
        if i == 0:
            right_border += int(windows_size * overlapping_area / 2)
        elif i > 0:
            left_border -= int(windows_size * overlapping_area / 2)
            right_border += int(windows_size * overlapping_area / 2)

        windows[i, 0, left_border:right_border] = numpy_signal[0, left_border:right_border]
        
    rfft_signals = np.fft.rfft(windows, axis=2)
    
    spectr = rfft_signals[:, :, :top_n_freq]
    return spectr.transpose(0, 2, 1)

# %%
spectr = make_overlapped_spectr(l_tts_train[1][0].numpy(), l_tts_train[1][1], windows_count=300, top_n_freq=20000)
spectr.shape
# Out:
# (300, 20000, 1)

# %%
ld.specshow(np.abs(spectr.reshape(spectr.shape[:2])).transpose(), y_axis='fft', x_axis='frames', sr=l_tts_train[1][1])

# %% [markdown]
# #### датасет

# %%
class OverlappedLibriDataset(LibriDataset):
    def __init__(self, libri_dataset, idxs: list, path: str):
        super().__init__(libri_dataset, idxs, path)

    def __getitem__(self, index):
        random_index = self.idxs[index]
        if not (os.path.exists(
                f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_0.npy"
        ) or os.path.exists(
                f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_1.npy"
        )):
            sound = self.libri_dataset[random_index]
            spectr = make_spectr_v2(sound[0],
                                    sound[1],
                                    window_type='hann',
                                    top_n_freq=TOP_N_FREQ,
                                    windows_count=WINDOWS_COUNT)
            img = np.abs(spectr.transpose())
            sex = id_2_sex_map[sound[4]]
            file_name = f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_{sex}.npy"
            with open(file_name, "wb") as f:
                np.save(f, img)
        else:
            file_name = f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_0.npy"
            if os.path.exists(file_name):
                with open(file_name, "rb") as f:
                    img = np.load(f, allow_pickle=True)
                    sex = 0
            else:
                file_name = f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_1.npy"
                if os.path.exists(file_name):
                    with open(file_name, "rb") as f:
                        img = np.load(f, allow_pickle=True)
                        sex = 1

        return torch.tensor(img).float().cuda(), torch.tensor(
            sex).float().cuda()

# %%
BATCH_SIZE = 256

data_train_overlapped_path = os.path.join(data_path, 'overlapped', 'train')
os.makedirs(data_train_overlapped_path, exist_ok=True)
print(data_train_overlapped_path)
overlapped_train_dataloader = DataLoader(OverlappedLibriDataset(
    l_tts_train, train_idxs, data_train_overlapped_path),
                                         batch_size=BATCH_SIZE,
                                         num_workers=0,
                                         shuffle=True)
overlapped_valid_dataloader = DataLoader(OverlappedLibriDataset(
    l_tts_train, valid_idxs, data_train_overlapped_path),
                                         num_workers=0,
                                         batch_size=BATCH_SIZE)
# Out:
# Y:/Documents/projects/libri_tts/freq_imgs\overlapped\train

# %% [markdown]
# #### цикл

# %%
overlapped_early_stop_callback = EarlyStopping(monitor='valid_loss',
                                    min_delta=0.001,
                                    patience=30,
                                    verbose=True,
                                    mode='min')
overlapped_val_loss_checkpoint = ModelCheckpoint(
    monitor='valid_loss',
    dirpath=work_dir + './overlapped_models/',
    filename='{epoch:02d}-{valid_loss:.4f}',
    save_top_k=1,
    verbose=True,
    mode='min')

overlapped_model = Model()

trainer = Trainer(
    max_epochs=EPOCHS,
    gpus=1,
    callbacks=[overlapped_early_stop_callback, overlapped_val_loss_checkpoint],
)  # resume_from_checkpoint=work_dir+'./pytorch_models/*' )
trainer.fit(model=overlapped_model,
            train_dataloader=overlapped_train_dataloader,
            val_dataloaders=overlapped_valid_dataloader)
f"best checkpoint path {overlapped_val_loss_checkpoint.best_model_path}"
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | model     | Sequential | 91.0 K
# 1 | loss      | BCELoss    | 0
# 2 | train_acc | Accuracy   | 0
# 3 | valid_acc | Accuracy   | 0
# -----------------------------------------
# 91.0 K    Trainable params
# 0         Non-trainable params
# 91.0 K    Total params
# 0.364     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved. New best score: 0.605
# Epoch 0, global step 58: valid_loss reached 0.60458 (best 0.60458), saving model to "Z:\Documents\projects\science\overlapped_models\epoch=00-valid_loss=0.6046.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.049 >= min_delta = 0.001. New best score: 0.556
# Epoch 1, global step 117: valid_loss reached 0.55555 (best 0.55555), saving model to "Z:\Documents\projects\science\overlapped_models\epoch=01-valid_loss=0.5556.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.030 >= min_delta = 0.001. New best score: 0.526
# Epoch 2, global step 176: valid_loss reached 0.52571 (best 0.52571), saving model to "Z:\Documents\projects\science\overlapped_models\epoch=02-valid_loss=0.5257.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.004 >= min_delta = 0.001. New best score: 0.521
# Epoch 3, global step 235: valid_loss reached 0.52144 (best 0.52144), saving model to "Z:\Documents\projects\science\overlapped_models\epoch=03-valid_loss=0.5214.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 4, global step 294: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.026 >= min_delta = 0.001. New best score: 0.496
# Epoch 5, global step 353: valid_loss reached 0.49589 (best 0.49589), saving model to "Z:\Documents\projects\science\overlapped_models\epoch=05-valid_loss=0.4959.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 6, global step 412: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 7, global step 471: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 8, global step 530: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 9, global step 589: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 10, global step 648: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.003 >= min_delta = 0.001. New best score: 0.492
# Epoch 11, global step 707: valid_loss reached 0.49242 (best 0.49242), saving model to "Z:\Documents\projects\science\overlapped_models\epoch=11-valid_loss=0.4924.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 12, global step 766: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 13, global step 825: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 14, global step 884: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 15, global step 943: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 16, global step 1002: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 17, global step 1061: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 18, global step 1120: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 19, global step 1179: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 20, global step 1238: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 21, global step 1297: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 22, global step 1356: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 23, global step 1415: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 24, global step 1474: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 25, global step 1533: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 26, global step 1592: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 27, global step 1651: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 28, global step 1710: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 29, global step 1769: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 30, global step 1828: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 31, global step 1887: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 32, global step 1946: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 33, global step 2005: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 34, global step 2064: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 35, global step 2123: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 36, global step 2182: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 37, global step 2241: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 38, global step 2300: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 39, global step 2359: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 40, global step 2418: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Monitored metric valid_loss did not improve in the last 30 records. Best score: 0.492. Signaling Trainer to stop.
# Epoch 41, global step 2477: valid_loss was not in top 1
# 'best checkpoint path Z:\\Documents\\projects\\science\\overlapped_models\\epoch=11-valid_loss=0.4924.ckpt'

# %%
overlapped_val_loss_checkpoint.best_model_path
# Out:
# 'Z:\\Documents\\projects\\science\\overlapped_models\\epoch=11-valid_loss=0.4924.ckpt'

# %%
overlapped_model = Model()
overlapped_model.load_state_dict(torch.load(overlapped_val_loss_checkpoint.best_model_path)['state_dict'])
overlapped_model = overlapped_model.cuda()

# %% [markdown]
# #### резы на тесте

# %%
with torch.no_grad():
    y_tests = []
    y_test_preds = []
    for x_test, y_test in tqdm(OverlappedLibriDataset(l_tts_train, test_idxs,
                                                data_train_overlapped_path)):
        y_tests.append(y_test.item())
        y_test_preds.append(overlapped_model.forward(x_test.unsqueeze(0)).item())
        
# средняя точность на тесте
((np.array(y_test_preds) > 0.5).astype(int) == np.array(y_tests)).mean()
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]
# 0.7326666666666667

# %%
(np.array(y_test_preds) > 0.5).astype(int)
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
np.array(y_tests).mean() # классы более менее сболансированны, так что можно обойтись accuracy
# Out:
# 0.609

# %% [markdown]
# На удивление модель с перекрытием окна дала результат чуть лучше +1% по accuracy.

# %% [markdown]
# ### модель с окном ханна для STFT

# %%
def make_overlapped_spectr_v2(numpy_signal: np.array,
                              signal_rate: int,
                              windows_count=1000,
                              overlapping_area=0.5,
                              window_type='hann',
                              top_n_freq=4000) -> np.array:
    n_samples = len(numpy_signal[0])
    hop_l = int(n_samples / windows_count)
    win_l = int(hop_l / (1 - overlapping_area / 2))
    return librosa.stft(numpy_signal[0],
                        hop_length=hop_l,
                        window=window_type,
                        n_fft=n_samples,
                        win_length=win_l
                       )[:top_n_freq, :windows_count]

# %%
# %%time
spectr = make_overlapped_spectr_v2(l_tts_train[1][0].numpy(),
                     l_tts_train[1][1],
                     windows_count=300,
                     top_n_freq=20000)
ld.specshow(np.abs(spectr),
            y_axis='fft',
            x_axis='frames',
            sr=l_tts_train[1][1])
spectr.shape
# Out:
# 362640 1208 1610
# Wall time: 23.9 s
# (20000, 300)

# %% [markdown]
# #### датасет

# %%
class OverlappedHahnLibriDataset(LibriDataset):
    def __init__(self, libri_dataset, idxs: list, path: str):
        super().__init__(libri_dataset, idxs, path)

    def __getitem__(self, index):
        random_index = self.idxs[index]
        if not (os.path.exists(
                f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_0.npy"
        ) or os.path.exists(
                f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_1.npy"
        )):
            sound = self.libri_dataset[random_index]
            spectr = make_overlapped_spectr_v2(sound[0].numpy(),
                                            sound[1],
                                            top_n_freq=TOP_N_FREQ,
                                            windows_count=WINDOWS_COUNT)
            img = np.abs(spectr[:,:, None].transpose())
            sex = id_2_sex_map[sound[4]]
            file_name = f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_{sex}.npy"
            with open(file_name, "wb") as f:
                np.save(f, img)
        else:
            file_name = f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_0.npy"
            if os.path.exists(file_name):
                with open(file_name, "rb") as f:
                    img = np.load(f, allow_pickle=True)
                    sex = 0
            else:
                file_name = f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_1.npy"
                if os.path.exists(file_name):
                    with open(file_name, "rb") as f:
                        img = np.load(f, allow_pickle=True)
                        sex = 1

        return torch.tensor(img).float().cuda(), torch.tensor(
            sex).float().cuda()

# %%
BATCH_SIZE = 256

data_train_overlapped_hahn_path = os.path.join(data_path, 'overlapped_hahn', 'train')
os.makedirs(data_train_overlapped_hahn_path, exist_ok=True)
print(data_train_overlapped_hahn_path)
overlapped_hahn_train_dataloader = DataLoader(OverlappedHahnLibriDataset(
    l_tts_train, train_idxs, data_train_overlapped_hahn_path),
                                         batch_size=BATCH_SIZE,
                                         num_workers=0,
                                         shuffle=True)
overlapped_hahn_valid_dataloader = DataLoader(OverlappedHahnLibriDataset(
    l_tts_train, valid_idxs, data_train_overlapped_hahn_path),
                                         num_workers=0,
                                         batch_size=BATCH_SIZE)
# Out:
# Y:/Documents/projects/libri_tts/freq_imgs\overlapped_hahn\train

# %% [markdown]
# #### цикл

# %%
overlapped_hahn_early_stop_callback = EarlyStopping(monitor='valid_loss',
                                    min_delta=0.001,
                                    patience=30,
                                    verbose=True,
                                    mode='min')
overlapped_hahn_val_loss_checkpoint = ModelCheckpoint(
    monitor='valid_loss',
    dirpath=work_dir + './overlapped_hahn_models/',
    filename='{epoch:02d}-{valid_loss:.4f}',
    save_top_k=1,
    verbose=True,
    mode='min')

overlapped_hahn_model = Model()

trainer = Trainer(
    max_epochs=EPOCHS,
    gpus=1,
    callbacks=[overlapped_hahn_early_stop_callback, overlapped_hahn_val_loss_checkpoint],
)  # resume_from_checkpoint=work_dir+'./pytorch_models/*' )
trainer.fit(model=overlapped_hahn_model,
            train_dataloader=overlapped_hahn_train_dataloader,
            val_dataloaders=overlapped_hahn_valid_dataloader)
f"best checkpoint path {overlapped_hahn_val_loss_checkpoint.best_model_path}"
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | model     | Sequential | 371 K
# 1 | loss      | BCELoss    | 0
# 2 | train_acc | Accuracy   | 0
# 3 | valid_acc | Accuracy   | 0
# -----------------------------------------
# 371 K     Trainable params
# 0         Non-trainable params
# 371 K     Total params
# 1.487     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved. New best score: 0.557
# Epoch 0, global step 58: valid_loss reached 0.55705 (best 0.55705), saving model to "Z:\Documents\projects\science\overlapped_hahn_models\epoch=00-valid_loss=0.5570.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.047 >= min_delta = 0.001. New best score: 0.510
# Epoch 1, global step 117: valid_loss reached 0.50966 (best 0.50966), saving model to "Z:\Documents\projects\science\overlapped_hahn_models\epoch=01-valid_loss=0.5097.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.007 >= min_delta = 0.001. New best score: 0.502
# Epoch 2, global step 176: valid_loss reached 0.50239 (best 0.50239), saving model to "Z:\Documents\projects\science\overlapped_hahn_models\epoch=02-valid_loss=0.5024.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 3, global step 235: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.020 >= min_delta = 0.001. New best score: 0.483
# Epoch 4, global step 294: valid_loss reached 0.48279 (best 0.48279), saving model to "Z:\Documents\projects\science\overlapped_hahn_models\epoch=04-valid_loss=0.4828.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.010 >= min_delta = 0.001. New best score: 0.473
# Epoch 5, global step 353: valid_loss reached 0.47255 (best 0.47255), saving model to "Z:\Documents\projects\science\overlapped_hahn_models\epoch=05-valid_loss=0.4725.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.011 >= min_delta = 0.001. New best score: 0.462
# Epoch 6, global step 412: valid_loss reached 0.46173 (best 0.46173), saving model to "Z:\Documents\projects\science\overlapped_hahn_models\epoch=06-valid_loss=0.4617.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.010 >= min_delta = 0.001. New best score: 0.452
# Epoch 7, global step 471: valid_loss reached 0.45213 (best 0.45213), saving model to "Z:\Documents\projects\science\overlapped_hahn_models\epoch=07-valid_loss=0.4521.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 8, global step 530: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 9, global step 589: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.016 >= min_delta = 0.001. New best score: 0.436
# Epoch 10, global step 648: valid_loss reached 0.43586 (best 0.43586), saving model to "Z:\Documents\projects\science\overlapped_hahn_models\epoch=10-valid_loss=0.4359.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.016 >= min_delta = 0.001. New best score: 0.420
# Epoch 11, global step 707: valid_loss reached 0.42010 (best 0.42010), saving model to "Z:\Documents\projects\science\overlapped_hahn_models\epoch=11-valid_loss=0.4201.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 12, global step 766: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 13, global step 825: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 14, global step 884: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.010 >= min_delta = 0.001. New best score: 0.410
# Epoch 15, global step 943: valid_loss reached 0.41030 (best 0.41030), saving model to "Z:\Documents\projects\science\overlapped_hahn_models\epoch=15-valid_loss=0.4103.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 16, global step 1002: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 17, global step 1061: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 18, global step 1120: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 19, global step 1179: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 20, global step 1238: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 21, global step 1297: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 22, global step 1356: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 23, global step 1415: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 24, global step 1474: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 25, global step 1533: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 26, global step 1592: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 27, global step 1651: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 28, global step 1710: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 29, global step 1769: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 30, global step 1828: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 31, global step 1887: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 32, global step 1946: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 33, global step 2005: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 34, global step 2064: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 35, global step 2123: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 36, global step 2182: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 37, global step 2241: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 38, global step 2300: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 39, global step 2359: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 40, global step 2418: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 41, global step 2477: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 42, global step 2536: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 43, global step 2595: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 44, global step 2654: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Monitored metric valid_loss did not improve in the last 30 records. Best score: 0.410. Signaling Trainer to stop.
# Epoch 45, global step 2713: valid_loss was not in top 1
# 'best checkpoint path Z:\\Documents\\projects\\science\\overlapped_hahn_models\\epoch=15-valid_loss=0.4103.ckpt'

# %%
overlapped_hahn_model = Model()
overlapped_hahn_model.load_state_dict(torch.load(overlapped_hahn_val_loss_checkpoint.best_model_path)['state_dict'])
overlapped_hahn_model = overlapped_hahn_model.cuda()

# %% [markdown]
# #### резы на тесте

# %%
test_idxs = np.arange(VALID_SET_SIZE + TRAIN_SET_SIZE, VALID_SET_SIZE + TRAIN_SET_SIZE + 3000)
with torch.no_grad():
    y_tests = []
    y_test_preds = []
    for x_test, y_test in tqdm(OverlappedHahnLibriDataset(l_tts_train, test_idxs,
                                                data_train_overlapped_hahn_path)):
        y_tests.append(y_test.item())
        y_test_preds.append(overlapped_hahn_model.forward(x_test.unsqueeze(0)).item())
        
# средняя точность на тесте
((np.array(y_test_preds) > 0.5).astype(int) == np.array(y_tests)).mean()
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]
# 0.76

# %% [markdown]
# тада! + 3 процента на тесте!

# %% [markdown]
# ### модель с переводом в амплитуды логарифмическую шкалу

# %%
# %%time
spectr = make_overlapped_spectr_v2(l_tts_train[1][0].numpy(),
                     l_tts_train[1][1],
                     windows_count=300,
                     top_n_freq=20000)
ld.specshow(np.log10(np.abs(spectr)),
            y_axis='log',
            x_axis='frames',
            sr=l_tts_train[1][1])
spectr.shape
# Out:
# Wall time: 24.1 s
# (20000, 300)

# %% [markdown]
# #### датасет

# %%
class OverlappedHahnLogLibriDataset(LibriDataset):
    def __init__(self, libri_dataset, idxs: list, path: str):
        super().__init__(libri_dataset, idxs, path)

    def __getitem__(self, index):
        random_index = self.idxs[index]
        if not (os.path.exists(
                f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_0.npy"
        ) or os.path.exists(
                f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_1.npy"
        )):
            sound = self.libri_dataset[random_index]
            spectr = make_overlapped_spectr_v2(sound[0].numpy(),
                                            sound[1],
                                            top_n_freq=TOP_N_FREQ,
                                            windows_count=WINDOWS_COUNT)
            img = np.abs(spectr[:,:, None].transpose())
            sex = id_2_sex_map[sound[4]]
            file_name = f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_{sex}.npy"
            with open(file_name, "wb") as f:
                np.save(f, img)
        else:
            file_name = f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_0.npy"
            if os.path.exists(file_name):
                with open(file_name, "rb") as f:
                    img = np.load(f, allow_pickle=True)
                    sex = 0
            else:
                file_name = f"{self.path}/{TOP_N_FREQ}f_{WINDOWS_COUNT}w_{random_index}_1.npy"
                if os.path.exists(file_name):
                    with open(file_name, "rb") as f:
                        img = np.load(f, allow_pickle=True)
                        sex = 1

        return torch.log10(torch.clip(torch.tensor(img), min=1e-14)).float().cuda(), torch.tensor(
            sex).float().cuda()

# %%
BATCH_SIZE = 256

data_train_overlapped_hahn_path = os.path.join(data_path, 'overlapped_hahn', 'train')
os.makedirs(data_train_overlapped_hahn_path, exist_ok=True)
print(data_train_overlapped_hahn_path)
overlapped_hahn_log_train_dataloader = DataLoader(OverlappedHahnLogLibriDataset(
    l_tts_train, train_idxs, data_train_overlapped_hahn_path),
                                         batch_size=BATCH_SIZE,
                                         num_workers=0,
                                         shuffle=True)
overlapped_hahn_log_valid_dataloader = DataLoader(OverlappedHahnLogLibriDataset(
    l_tts_train, valid_idxs, data_train_overlapped_hahn_path),
                                         num_workers=0,
                                         batch_size=BATCH_SIZE)
# Out:
# Y:/Documents/projects/libri_tts/freq_imgs\overlapped_hahn\train

# %% [markdown]
# #### цикл

# %%
overlapped_hahn_log_early_stop_callback = EarlyStopping(monitor='valid_loss',
                                    min_delta=0.001,
                                    patience=30,
                                    verbose=True,
                                    mode='min')
overlapped_hahn_log_val_loss_checkpoint = ModelCheckpoint(
    monitor='valid_loss',
    dirpath=work_dir + './overlapped_hahn_log_models/',
    filename='{epoch:02d}-{valid_loss:.4f}',
    save_top_k=1,
    verbose=True,
    mode='min')

overlapped_hahn_log_model = Model()

trainer = Trainer(
    max_epochs=EPOCHS,
    gpus=1,
    callbacks=[overlapped_hahn_log_early_stop_callback, overlapped_hahn_log_val_loss_checkpoint],
)  # resume_from_checkpoint=work_dir+'./pytorch_models/*' )
trainer.fit(model=overlapped_hahn_log_model,
            train_dataloader=overlapped_hahn_log_train_dataloader,
            val_dataloaders=overlapped_hahn_log_valid_dataloader)
f"best checkpoint path {overlapped_hahn_log_val_loss_checkpoint.best_model_path}"
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | model     | Sequential | 371 K
# 1 | loss      | BCELoss    | 0
# 2 | train_acc | Accuracy   | 0
# 3 | valid_acc | Accuracy   | 0
# -----------------------------------------
# 371 K     Trainable params
# 0         Non-trainable params
# 371 K     Total params
# 1.487     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved. New best score: 0.617
# Epoch 0, global step 58: valid_loss reached 0.61722 (best 0.61722), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=00-valid_loss=0.6172.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.056 >= min_delta = 0.001. New best score: 0.561
# Epoch 1, global step 117: valid_loss reached 0.56139 (best 0.56139), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=01-valid_loss=0.5614.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.050 >= min_delta = 0.001. New best score: 0.511
# Epoch 2, global step 176: valid_loss reached 0.51137 (best 0.51137), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=02-valid_loss=0.5114.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.033 >= min_delta = 0.001. New best score: 0.478
# Epoch 3, global step 235: valid_loss reached 0.47847 (best 0.47847), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=03-valid_loss=0.4785.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.009 >= min_delta = 0.001. New best score: 0.470
# Epoch 4, global step 294: valid_loss reached 0.46982 (best 0.46982), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=04-valid_loss=0.4698.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 5, global step 353: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.007 >= min_delta = 0.001. New best score: 0.463
# Epoch 6, global step 412: valid_loss reached 0.46309 (best 0.46309), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=06-valid_loss=0.4631.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 7, global step 471: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.029 >= min_delta = 0.001. New best score: 0.434
# Epoch 8, global step 530: valid_loss reached 0.43359 (best 0.43359), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=08-valid_loss=0.4336.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 9, global step 589: valid_loss reached 0.43333 (best 0.43333), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=09-valid_loss=0.4333.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 10, global step 648: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.015 >= min_delta = 0.001. New best score: 0.419
# Epoch 11, global step 707: valid_loss reached 0.41872 (best 0.41872), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=11-valid_loss=0.4187.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 12, global step 766: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.004 >= min_delta = 0.001. New best score: 0.415
# Epoch 13, global step 825: valid_loss reached 0.41517 (best 0.41517), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=13-valid_loss=0.4152.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.003 >= min_delta = 0.001. New best score: 0.412
# Epoch 14, global step 884: valid_loss reached 0.41187 (best 0.41187), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=14-valid_loss=0.4119.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.015 >= min_delta = 0.001. New best score: 0.397
# Epoch 15, global step 943: valid_loss reached 0.39703 (best 0.39703), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=15-valid_loss=0.3970.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.395
# Epoch 16, global step 1002: valid_loss reached 0.39467 (best 0.39467), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=16-valid_loss=0.3947.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 17, global step 1061: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.392
# Epoch 18, global step 1120: valid_loss reached 0.39220 (best 0.39220), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=18-valid_loss=0.3922.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 19, global step 1179: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 20, global step 1238: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.001 >= min_delta = 0.001. New best score: 0.391
# Epoch 21, global step 1297: valid_loss reached 0.39105 (best 0.39105), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=21-valid_loss=0.3911.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 22, global step 1356: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 23, global step 1415: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 24, global step 1474: valid_loss reached 0.39089 (best 0.39089), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=24-valid_loss=0.3909.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 25, global step 1533: valid_loss reached 0.39057 (best 0.39057), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=25-valid_loss=0.3906.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 26, global step 1592: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 27, global step 1651: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 28, global step 1710: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 29, global step 1769: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 30, global step 1828: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 31, global step 1887: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 32, global step 1946: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 33, global step 2005: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 34, global step 2064: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 35, global step 2123: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 36, global step 2182: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 37, global step 2241: valid_loss reached 0.39049 (best 0.39049), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=37-valid_loss=0.3905.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 38, global step 2300: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 39, global step 2359: valid_loss reached 0.39048 (best 0.39048), saving model to "Z:\Documents\projects\science\overlapped_hahn_log_models\epoch=39-valid_loss=0.3905.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 40, global step 2418: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 41, global step 2477: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 42, global step 2536: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 43, global step 2595: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 44, global step 2654: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 45, global step 2713: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 46, global step 2772: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 47, global step 2831: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 48, global step 2890: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 49, global step 2949: valid_loss was not in top 1
# 'best checkpoint path Z:\\Documents\\projects\\science\\overlapped_hahn_log_models\\epoch=39-valid_loss=0.3905.ckpt'

# %% [markdown]
# #### резы на тесте

# %%
overlapped_hahn_log_model = Model()
overlapped_hahn_log_model.load_state_dict(torch.load(overlapped_hahn_log_val_loss_checkpoint.best_model_path)['state_dict'])
overlapped_hahn_log_model = overlapped_hahn_log_model.cuda()

# %%
test_idxs = np.arange(VALID_SET_SIZE + TRAIN_SET_SIZE, VALID_SET_SIZE + TRAIN_SET_SIZE + 3000)
with torch.no_grad():
    y_tests = []
    y_test_preds = []
    for x_test, y_test in tqdm(OverlappedHahnLogLibriDataset(l_tts_train, test_idxs,
                                                data_train_overlapped_hahn_path)):
        y_tests.append(y_test.item())
        y_test_preds.append(overlapped_hahn_log_model.forward(x_test.unsqueeze(0).cuda()).item())
        
# средняя точность на тесте
((np.array(y_test_preds) > 0.5).astype(int) == np.array(y_tests)).mean()
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]
# 0.7623333333333333

# %% [markdown]
# та-да! ещё один процент!

# %% [markdown]
# ### используем MELSPEC

# %%
def to_mel_scale(freq: float):
    return 2595 * np.log10(1 + freq / 700)

def to_mel_scale(freq: np.array):
    return 2595 * np.log10(1 + freq / 700)


def from_mel_scale(mel_freq: float):
    return 700 * (10**(mel_freq / 2595) - 1)

# %%
# эти все константы по хорошему надо grid_search'ем подбирать
num_mels = 22 # 88/4 пианино
max_freq = 1025
min_freq = 0

# %%
max_mel_freq = to_mel_scale(max_freq)
min_mel_freq = to_mel_scale(min_freq)
mel_delta = (max_mel_freq- min_mel_freq)  / (num_mels+1)
max_mel_freq, min_mel_freq, mel_delta
# Out:
# (1016.4382991301187, 0.0, 44.192969527396464)

# %%
mel_centroids = [(min_mel_freq + i * mel_delta)
                 for i in range(1, num_mels + 1)]
freq_centroids = [from_mel_scale(c) for c in mel_centroids]
freq_centroids
# Out:
# [27.994479625309232,
#  57.10851766417839,
#  87.38688762403271,
#  118.87615359949936,
#  151.6247418817748,
#  185.68301543180138,
#  221.10335133178447,
#  257.9402213341584,
#  296.2502756318775,
#  336.0924299788566,
#  377.5279562945427,
#  420.62057689195524,
#  465.43656247410416,
#  512.0448340494925,
#  560.5170689234351,
#  610.9278109281946,
#  663.3545850614529,
#  717.8780167094169,
#  774.5819556379107,
#  833.5536049421312,
#  894.8836551533773,
#  958.6664237089914]

# %%
def make_bins(freq_centroids: list, min_freq: float, max_freq: float) -> list:
    bins = []

    for i in range(0, len(freq_centroids)):
        zeros = np.zeros(max_freq - min_freq)

        left = int(freq_centroids[i - 1] if i > 0 else min_freq)
        center = int(freq_centroids[i])
        right = int(freq_centroids[i + 1] if i < (len(freq_centroids) -
                                                  1) else max_freq)
        
        zeros[left:center] = np.linspace(start=0, num=(center - left), stop=1)
        zeros[center:right] = np.linspace(start=1,
                                          num=(right - center),
                                          stop=0)

        bins.append(zeros)

    return np.array(bins)


mel_bins = make_bins(freq_centroids, min_freq, max_freq)

# %%
# вот так выглядит bin'ы
plt.rcParams["figure.figsize"] = (20,3)
for mel_b in mel_bins:
    plt.plot(mel_b)
None

# %%
def make_overlapped_spectr_v3(numpy_signal: np.array,
                              signal_rate: int,
                              windows_count=1000,
                              overlapping_area=0.5,
                              window_type='hann',
                              n_fft=512,
                              top_n_freq=4000) -> np.array:
    n_samples = len(numpy_signal[0])
    hop_l = int(n_samples / windows_count)
    return librosa.stft(numpy_signal[0],
                        hop_length=hop_l,
                        window=window_type,
                        n_fft=n_fft,
#                         n_fft=top_n_freq,
#                         win_length=win_l
                       )[:int(top_n_freq/2), :windows_count]

spectr = make_overlapped_spectr_v2(l_tts_train[1][0].numpy(),
                     l_tts_train[1][1],
                     windows_count=300,
                     top_n_freq=20000)
print(spectr.shape)
# Out:
# 362640 1208 1610
# (20000, 300)

# %%
melspectr = np.matmul(mel_bins , spectr)

plt.rcParams["figure.figsize"] = (10,5)
ld.specshow(np.abs(melspectr), x_axis='frames', y_axis='mel',sr=l_tts_train[1][1])

# %%
def get_melspec(signal, sr: int, n_fft=512, windows_count=300, n_mels=22):
    hop_l = int(len(signal[0]) / (windows_count - 1))
    librosa_melspec = librosa.feature.melspectrogram(
        y=signal,
        sr=sr,
        n_fft=n_fft,
        #                                                  fmax=max_freq,
        #                                                  win_length= 1610,#362640,
        hop_length=hop_l,
        n_mels=n_mels)
    librosa_melspec = librosa_melspec.reshape(librosa_melspec.shape[1:])
    return librosa_melspec[:, :windows_count, np.newaxis].transpose(2,0,1)


mspc = get_melspec(l_tts_train[1][0].numpy(), sr=l_tts_train[1][1])
ld.specshow(np.log10(mspc.reshape(22,300)), x_axis='frames', y_axis='mel', sr=l_tts_train[1][1])

# %% [markdown]
# #### датасет

# %%
class MelSpecLibriDataset(LibriDataset):
    def __init__(self, libri_dataset, idxs: list, path: str, max_freq=TOP_N_FREQ):
        super().__init__(libri_dataset, idxs, path)

    def __getitem__(self, index):
        random_index = self.idxs[index]
        sound = self.libri_dataset[random_index]
        img = get_melspec(sound[0].numpy(), sound[1])
        sex = id_2_sex_map[sound[4]]        
        melspectr = np.log10(np.clip(img, a_min=1e-10, a_max=1e15))
#         print(melspectr.shape)
        return torch.tensor(melspectr).float().cuda(), torch.tensor(
            sex).float().cuda()

# %%
BATCH_SIZE = 256

data_train_mel_path = os.path.join(data_path, 'overlapped_hahn', 'train')
os.makedirs(data_train_mel_path, exist_ok=True)
print(data_train_mel_path)
mel_train_dataloader = DataLoader(MelSpecLibriDataset(l_tts_train,
                                                      train_idxs,
                                                      data_train_mel_path,
                                                      max_freq=max_freq),
                                  batch_size=BATCH_SIZE,
                                  num_workers=0,
                                  shuffle=True)
mel_valid_dataloader = DataLoader(MelSpecLibriDataset(l_tts_train,
                                                      valid_idxs,
                                                      data_train_mel_path,
                                                      max_freq=max_freq),
                                  num_workers=0,
                                  batch_size=BATCH_SIZE)
# Out:
# Y:/Documents/projects/libri_tts/freq_imgs\overlapped_hahn\train

# %% [markdown]
# #### цикл

# %%
def make_model2():
    model = torch.nn.Sequential(
        torch.nn.Conv2d(1, 15, kernel_size=(3,3), stride=2, padding_mode='zeros'),
        torch.nn.MaxPool2d(kernel_size=(3,3), stride=2),
        torch.nn.LeakyReLU(),
        torch.nn.Conv2d(15, 35, kernel_size=(3,3), stride=2, padding_mode='zeros'),
#         torch.nn.MaxPool2d(kernel_size=(3,3), stride=2),
        torch.nn.LeakyReLU(),
        torch.nn.Flatten(),
        torch.nn.Linear(1260,1),
        torch.nn.Sigmoid()
    )
    return model.cuda()



mel_model = Model(model=make_model2())

# %%
mel_early_stop_callback = EarlyStopping(monitor='valid_loss',
                                    min_delta=0.001,
                                    patience=30,
                                    verbose=True,
                                    mode='min')
mel_val_loss_checkpoint = ModelCheckpoint(
    monitor='valid_loss',
    dirpath=work_dir + './overlapped_mel_models/',
    filename='{epoch:02d}-{valid_loss:.4f}',
    save_top_k=1,
    verbose=True,
    mode='min')


trainer = Trainer(
    max_epochs=EPOCHS,
    gpus=1,
    callbacks=[mel_early_stop_callback, mel_val_loss_checkpoint],
)  # resume_from_checkpoint=work_dir+'./pytorch_models/*' )
trainer.fit(model=mel_model,
            train_dataloader=mel_train_dataloader,
            val_dataloaders=mel_valid_dataloader)
f"best checkpoint path {mel_val_loss_checkpoint.best_model_path}"
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | model     | Sequential | 6.2 K
# 1 | loss      | BCELoss    | 0
# 2 | train_acc | Accuracy   | 0
# 3 | valid_acc | Accuracy   | 0
# -----------------------------------------
# 6.2 K     Trainable params
# 0         Non-trainable params
# 6.2 K     Total params
# 0.025     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved. New best score: 0.676
# Epoch 0, global step 58: valid_loss reached 0.67584 (best 0.67584), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=00-valid_loss=0.6758.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.047 >= min_delta = 0.001. New best score: 0.629
# Epoch 1, global step 117: valid_loss reached 0.62876 (best 0.62876), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=01-valid_loss=0.6288.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.096 >= min_delta = 0.001. New best score: 0.533
# Epoch 2, global step 176: valid_loss reached 0.53255 (best 0.53255), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=02-valid_loss=0.5325.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.049 >= min_delta = 0.001. New best score: 0.484
# Epoch 3, global step 235: valid_loss reached 0.48371 (best 0.48371), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=03-valid_loss=0.4837.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.011 >= min_delta = 0.001. New best score: 0.473
# Epoch 4, global step 294: valid_loss reached 0.47268 (best 0.47268), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=04-valid_loss=0.4727.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.055 >= min_delta = 0.001. New best score: 0.418
# Epoch 5, global step 353: valid_loss reached 0.41796 (best 0.41796), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=05-valid_loss=0.4180.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 6, global step 412: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.034 >= min_delta = 0.001. New best score: 0.384
# Epoch 7, global step 471: valid_loss reached 0.38388 (best 0.38388), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=07-valid_loss=0.3839.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.021 >= min_delta = 0.001. New best score: 0.363
# Epoch 8, global step 530: valid_loss reached 0.36254 (best 0.36254), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=08-valid_loss=0.3625.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 9, global step 589: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.034 >= min_delta = 0.001. New best score: 0.328
# Epoch 10, global step 648: valid_loss reached 0.32842 (best 0.32842), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=10-valid_loss=0.3284.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.009 >= min_delta = 0.001. New best score: 0.319
# Epoch 11, global step 707: valid_loss reached 0.31895 (best 0.31895), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=11-valid_loss=0.3189.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 12, global step 766: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.024 >= min_delta = 0.001. New best score: 0.295
# Epoch 13, global step 825: valid_loss reached 0.29470 (best 0.29470), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=13-valid_loss=0.2947.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 14, global step 884: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.005 >= min_delta = 0.001. New best score: 0.290
# Epoch 15, global step 943: valid_loss reached 0.28987 (best 0.28987), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=15-valid_loss=0.2899.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.003 >= min_delta = 0.001. New best score: 0.287
# Epoch 16, global step 1002: valid_loss reached 0.28701 (best 0.28701), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=16-valid_loss=0.2870.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 17, global step 1061: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.285
# Epoch 18, global step 1120: valid_loss reached 0.28544 (best 0.28544), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=18-valid_loss=0.2854.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.283
# Epoch 19, global step 1179: valid_loss reached 0.28332 (best 0.28332), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=19-valid_loss=0.2833.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 20, global step 1238: valid_loss reached 0.28330 (best 0.28330), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=20-valid_loss=0.2833.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.281
# Epoch 21, global step 1297: valid_loss reached 0.28115 (best 0.28115), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=21-valid_loss=0.2812.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 22, global step 1356: valid_loss reached 0.28078 (best 0.28078), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=22-valid_loss=0.2808.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 23, global step 1415: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 24, global step 1474: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.003 >= min_delta = 0.001. New best score: 0.279
# Epoch 25, global step 1533: valid_loss reached 0.27865 (best 0.27865), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=25-valid_loss=0.2786.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.277
# Epoch 26, global step 1592: valid_loss reached 0.27687 (best 0.27687), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=26-valid_loss=0.2769.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 27, global step 1651: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 28, global step 1710: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.001 >= min_delta = 0.001. New best score: 0.276
# Epoch 29, global step 1769: valid_loss reached 0.27580 (best 0.27580), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=29-valid_loss=0.2758.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.001 >= min_delta = 0.001. New best score: 0.275
# Epoch 30, global step 1828: valid_loss reached 0.27476 (best 0.27476), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=30-valid_loss=0.2748.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 31, global step 1887: valid_loss reached 0.27431 (best 0.27431), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=31-valid_loss=0.2743.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 32, global step 1946: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 33, global step 2005: valid_loss reached 0.27417 (best 0.27417), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=33-valid_loss=0.2742.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 34, global step 2064: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 35, global step 2123: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 36, global step 2182: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 37, global step 2241: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 38, global step 2300: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 39, global step 2359: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 40, global step 2418: valid_loss reached 0.27396 (best 0.27396), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=40-valid_loss=0.2740.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Metric valid_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.273
# Epoch 41, global step 2477: valid_loss reached 0.27317 (best 0.27317), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=41-valid_loss=0.2732.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 42, global step 2536: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 43, global step 2595: valid_loss reached 0.27315 (best 0.27315), saving model to "Z:\Documents\projects\science\overlapped_mel_models\epoch=43-valid_loss=0.2731.ckpt" as top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 44, global step 2654: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 45, global step 2713: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 46, global step 2772: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 47, global step 2831: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 48, global step 2890: valid_loss was not in top 1
# Validating: 0it [00:00, ?it/s]
# Epoch 49, global step 2949: valid_loss was not in top 1
# 'best checkpoint path Z:\\Documents\\projects\\science\\overlapped_mel_models\\epoch=43-valid_loss=0.2731.ckpt'

# %% [markdown]
# #### резы на тесте

# %%
mel_model = Model(model=make_model2())
mel_model.load_state_dict(torch.load(mel_val_loss_checkpoint.best_model_path)['state_dict'])
mel_model = mel_model.cuda()

# %%
test_idxs = np.arange(VALID_SET_SIZE + TRAIN_SET_SIZE, VALID_SET_SIZE + TRAIN_SET_SIZE + 3000)
with torch.no_grad():
    y_tests = []
    y_test_preds = []
    for x_test, y_test in tqdm(MelSpecLibriDataset(l_tts_train, test_idxs,
                                                data_train_overlapped_hahn_path)):
        y_tests.append(y_test.item())
        y_test_preds.append(mel_model.forward(x_test.unsqueeze(0).cuda()).item())
        
# средняя точность на тесте
((np.array(y_test_preds) > 0.5).astype(int) == np.array(y_tests)).mean()
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]
# 0.876

# %% [markdown]
# ## тензорборда и заключение
#
# 1. **melspec** не стал использовать так как хотелось разобраться как оно работает, и если честно не успел разобраться. А просто в **librosa** вызвать **librosa.feature.melspectrogram** рука не поднялась.
#
# 2. на удивление перекрытые окна для ффт не обучились от слова совсем, может был какой баг но я не нашёл. Перекрывающиеся окно как-то тоже можно было сделать через **librosa.core.spectrum.util.frame**, но хотелось досконально разобраться, может что и получилось.
#
# 3. кажется можно было нормальзовать амплитуды на входе в нейронку, но заморачиваться я не стал, в конце концов так делают чтобы различные по характеристикам фичи влияли одинакого, а в моём случае все фичи были одной природы
#
# 4. стоит обучиться на всё датасете, но преобразования у меня слишком громоздкие, и делаются долго, а на windows num_workers в даталоадерах странно работают. Да и я по срокам уже завалил. Так что времени уже нет.

# %%
# !pip3 freeze > requirements.txt

# %%
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs/  --port=8008
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 8008 (pid 25952), started 4 days, 0:39:21 ago. (Use '!kill 25952' to kill it.)
#       <iframe id="tensorboard-frame-7bc40e97901bb82e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7bc40e97901bb82e");
#           const url = new URL("/", window.location);
#           const port = 8008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# - 14 это обычная сетка.
# - 15 это с перекрывающимися окнами.
# - 17 - пересекающиеся фреймы с окном ханна.
# - 18 - с логарифмом апмлитуды
# - 27 - логарифм мелспектрограммы
